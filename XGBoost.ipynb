# %%
import pandas as pd
import os
from functools import reduce

# Thư mục chứa các mô hình
root_folder = '/kaggle/input/consis-dsc-prediction'
model_folders = ['erniem', 'xlmr', 'deberta', 'cross', 'roberta', 'dvt']
train_file = 'dev_predictions_with_probs.csv'
test_file = 'submit_with_probs_privatetest.csv'

def feature_engineering(root_folder, model_folders, file, train=True):
    model_dfs = []
    
    for model in model_folders:
        model_path = os.path.join(root_folder, model)
        df_list = []
    
        # Stack 5 folds theo chiều dọc
        for i in range(5):
            fold_path = os.path.join(model_path, f'fold_{i}', file)
            df = pd.read_csv(fold_path)
            df = df[['id', 'prob_intrinsic', 'prob_no', 'prob_extrinsic']]
            df_list.append(df)
    
        if train: 
            processed_df = pd.concat(df_list, axis=0, ignore_index=True)
        else: 
            # Average xác suất
            all_df = pd.concat(df_list)
            processed_df = all_df.groupby("id").mean().reset_index()
    
        # Đổi tên cột để phân biệt các mô hình
        processed_df = processed_df.rename(columns={
            'prob_intrinsic': f'{model}_prob_intrinsic',
            'prob_no': f'{model}_prob_no',
            'prob_extrinsic': f'{model}_prob_extrinsic'
        })
    
        model_dfs.append(processed_df)
    
    # Gộp các model lại theo chiều ngang dựa trên 'id'
    final_df = reduce(lambda left, right: pd.merge(left, right, on='id'), model_dfs)
    return final_df

train_meta = feature_engineering(root_folder, model_folders, file=train_file)
train_meta
# Out:
#                                         id  erniem_prob_intrinsic  \
# 0     db7a89c6-2a6a-42af-beef-58e557ecc819               0.015204
# 1     10fca062-d343-4eca-8434-93c7a8aa5e0e               0.025574
# 2     ece8eb9e-d6bb-407a-a567-d9531861c603               0.003886
# 3     b613217f-df2a-491e-8326-25811a31eb09               0.308794
# 4     6a00bac9-3de4-4144-90c6-4e080c160d43               0.986726
# ...                                    ...                    ...
# 6995  df859b5e-49ea-4b67-bc86-e01073521977               0.033319
# 6996  05d911a1-6a5c-4ed6-8a4b-4a111200c193               0.950903
# 6997  e8de77bc-3bea-4328-bf5d-3321ff767e69               0.009904
# 6998  4f7d3a5c-d395-43f0-a941-9ae2aa4b8632               0.013788
# 6999  7513ce4c-3959-4f1a-a197-fb66449f90a7               0.025176
#
#       erniem_prob_no  erniem_prob_extrinsic  xlmr_prob_intrinsic  \
# 0           0.966010               0.018786             0.019164
# 1           0.005776               0.968650             0.068519
# 2           0.990234               0.005881             0.005762
# 3           0.008378               0.682828             0.930336
# 4           0.001893               0.011380             0.983213
# ...              ...                    ...                  ...
# 6995        0.002976               0.963705             0.094277
# 6996        0.011749               0.037349             0.991391
# 6997        0.983390               0.006706             0.010554
# 6998        0.976917               0.009295             0.018545
# 6999        0.003616               0.971209             0.036685
#
#       xlmr_prob_no  xlmr_prob_extrinsic  deberta_prob_intrinsic  \
# 0         0.965985             0.014851                0.038892
# 1         0.006468             0.925014                0.223679
# 2         0.989063             0.005175                0.679647
# 3         0.003383             0.066281                0.739829
# 4         0.004952             0.011835                0.973340
# ...            ...                  ...                     ...
# 6995      0.003014             0.902709                0.083899
# 6996      0.002439             0.006170                0.949420
# 6997      0.986566             0.002880                0.053380
# 6998      0.951016             0.030439                0.038515
# 6999      0.005337             0.957979                0.047953
#
#       deberta_prob_no  deberta_prob_extrinsic  cross_prob_intrinsic  \
# 0            0.890406                0.070702              0.018710
# 1            0.014619                0.761702              0.018768
# 2            0.205793                0.114560              0.072594
# 3            0.022905                0.237266              0.914723
# 4            0.004083                0.022577              0.988244
# ...               ...                     ...                   ...
# 6995         0.006147                0.909954              0.031920
# 6996         0.002340                0.048241              0.953631
# 6997         0.889967                0.056652              0.016064
# 6998         0.887469                0.074016              0.010037
# 6999         0.007692                0.944354              0.025683
#
#       cross_prob_no  cross_prob_extrinsic  roberta_prob_intrinsic  \
# 0          0.923733              0.057557                0.012265
# 1          0.003533              0.977699                0.044158
# 2          0.893676              0.033729                0.017415
# 3          0.003096              0.082181                0.771447
# 4          0.000867              0.010889                0.992483
# ...             ...                   ...                     ...
# 6995       0.004306              0.963774                0.029042
# 6996       0.008644              0.037725                0.983543
# 6997       0.940588              0.043348                0.008599
# 6998       0.981783              0.008180                0.004185
# 6999       0.001805              0.972513                0.137096
#
#       roberta_prob_no  roberta_prob_extrinsic  dvt_prob_intrinsic  \
# 0            0.959150                0.028585            0.087124
# 1            0.016361                0.939481            0.112689
# 2            0.963567                0.019018            0.039752
# 3            0.004139                0.224414            0.828249
# 4            0.000393                0.007125            0.922774
# ...               ...                     ...                 ...
# 6995         0.005697                0.965261            0.064006
# 6996         0.001848                0.014609            0.875540
# 6997         0.979765                0.011636            0.054726
# 6998         0.969410                0.026404            0.147210
# 6999         0.009799                0.853106            0.044791
#
#       dvt_prob_no  dvt_prob_extrinsic
# 0        0.882724            0.030151
# 1        0.014523            0.872788
# 2        0.940535            0.019713
# 3        0.040226            0.131525
# 4        0.021137            0.056089
# ...           ...                 ...
# 6995     0.016565            0.919429
# 6996     0.069283            0.055177
# 6997     0.928317            0.016958
# 6998     0.708837            0.143953
# 6999     0.017890            0.937320
#
# [7000 rows x 19 columns]

# %%
test_meta = feature_engineering(root_folder, model_folders, file=test_file, train=False)
test_meta
# Out:
#                                         id  erniem_prob_intrinsic  \
# 0     0017c593-6648-4eb3-91ca-fd15a7c900d3               0.015454
# 1     0028c3a9-1beb-4644-8047-e890aa8680c8               0.027923
# 2     005197c9-45f9-44db-8442-5398d2f21999               0.027206
# 3     005687f6-5ffe-4d0d-9838-c98434df57e1               0.057078
# 4     006d47a4-4b66-4531-a747-97c6eb1e92f1               0.855520
# ...                                    ...                    ...
# 1995  ff48052f-4717-4e85-8823-f754b9f3bf25               0.006389
# 1996  ff5438f1-4987-41d1-aa30-3902190b16b8               0.978738
# 1997  ffc58416-c1c5-43ec-a707-a5e55354c53f               0.030662
# 1998  fff8b237-5029-451f-93a5-dd141328d552               0.952190
# 1999  fffa54af-59df-40bd-8ba1-3f2331bb2272               0.041468
#
#       erniem_prob_no  erniem_prob_extrinsic  xlmr_prob_intrinsic  \
# 0           0.965804               0.018742             0.007345
# 1           0.938700               0.033377             0.624169
# 2           0.003586               0.969208             0.015833
# 3           0.615861               0.327061             0.282155
# 4           0.069167               0.075313             0.180062
# ...              ...                    ...                  ...
# 1995        0.986769               0.006842             0.018256
# 1996        0.003199               0.018063             0.893180
# 1997        0.004237               0.965101             0.028510
# 1998        0.016029               0.031781             0.914793
# 1999        0.008461               0.950071             0.047492
#
#       xlmr_prob_no  xlmr_prob_extrinsic  deberta_prob_intrinsic  \
# 0         0.987312             0.005343                0.025299
# 1         0.276705             0.099126                0.212251
# 2         0.003313             0.980854                0.030894
# 3         0.090570             0.627275                0.078673
# 4         0.773223             0.046715                0.382950
# ...            ...                  ...                     ...
# 1995      0.974350             0.007393                0.027080
# 1996      0.038274             0.068546                0.956307
# 1997      0.006824             0.964666                0.062320
# 1998      0.050606             0.034602                0.602727
# 1999      0.009417             0.943091                0.061842
#
#       deberta_prob_no  deberta_prob_extrinsic  cross_prob_intrinsic  \
# 0            0.954350                0.020351              0.007703
# 1            0.675393                0.112356              0.451239
# 2            0.007363                0.961743              0.011185
# 3            0.350546                0.570781              0.024267
# 4            0.460795                0.156255              0.591131
# ...               ...                     ...                   ...
# 1995         0.960232                0.012688              0.015096
# 1996         0.003259                0.040433              0.978979
# 1997         0.006705                0.930975              0.025298
# 1998         0.197334                0.199939              0.692344
# 1999         0.013647                0.924511              0.057486
#
#       cross_prob_no  cross_prob_extrinsic  roberta_prob_intrinsic  \
# 0          0.973846              0.018450                0.002935
# 1          0.082003              0.466758                0.101108
# 2          0.001850              0.986965                0.018449
# 3          0.010482              0.965250                0.009121
# 4          0.171922              0.236947                0.179059
# ...             ...                   ...                     ...
# 1995       0.966359              0.018545                0.006791
# 1996       0.002182              0.018839                0.995341
# 1997       0.002176              0.972526                0.054140
# 1998       0.040982              0.266674                0.671341
# 1999       0.043941              0.898573                0.015323
#
#       roberta_prob_no  roberta_prob_extrinsic  dvt_prob_intrinsic  \
# 0            0.992803                0.004262            0.044080
# 1            0.867477                0.031415            0.320860
# 2            0.004879                0.976672            0.058649
# 3            0.908293                0.082586            0.166623
# 4            0.642232                0.178708            0.488169
# ...               ...                     ...                 ...
# 1995         0.988143                0.005066            0.046676
# 1996         0.000461                0.004198            0.719856
# 1997         0.004788                0.941072            0.051634
# 1998         0.245320                0.083339            0.362852
# 1999         0.008312                0.976365            0.110381
#
#       dvt_prob_no  dvt_prob_extrinsic
# 0        0.929475            0.026445
# 1        0.631154            0.047986
# 2        0.016921            0.924429
# 3        0.022330            0.811047
# 4        0.457006            0.054825
# ...           ...                 ...
# 1995     0.919877            0.033447
# 1996     0.125523            0.154621
# 1997     0.012386            0.935980
# 1998     0.568732            0.068415
# 1999     0.015329            0.874291
#
# [2000 rows x 19 columns]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Đọc dữ liệu nhãn
train_df = pd.read_csv('/kaggle/input/dsc-2025-dataset/train_dsc.csv')  # chứa 'id' và 'label' (chuỗi)

# Encode nhãn (chuỗi -> số nguyên)
le = LabelEncoder()
train_df['label_encoded'] = le.fit_transform(train_df['label'])

# Gộp với train_meta theo 'id' để tạo X, y tương ứng
merged_df = pd.merge(train_meta, train_df[['id', 'label_encoded']], on='id')

# Tách X và y
X = merged_df.drop(columns=['id', 'label_encoded'])
y = merged_df['label_encoded']

# %%
import os
import random
import numpy as np

from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# ==========================
# 1. Fix toàn bộ random seed
# ==========================
seed = 22520465
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)

# ==========================
# 2. Khởi tạo model XGBoost
# ==========================
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=seed,
    tree_method='hist',     # histogram (CPU & GPU đều hỗ trợ)
    device='cuda'           # GPU CUDA (đổi thành 'cpu' nếu muốn tuyệt đối deterministic)
)

# ==========================
# 3. Grid search hyperparams
# ==========================
param_grid = {
    'n_estimators': [300, 500, 700],
    'max_depth': [3, 6],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1],
    'colsample_bytree': [0.8, 1],
    'gamma': [0, 0.1, 0.5],
}

# ==========================
# 4. CV với random_state cố định
# ==========================
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=cv,
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2
)

# ==========================
# 5. Train & Inference
# ==========================
grid_search.fit(X, y)

print("Best params:", grid_search.best_params_)
print("Best CV F1 Macro:", grid_search.best_score_)
model = grid_search
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [00:39:37] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [00:39:37] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [00:39:38] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [00:39:38] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  17.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  27.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  19.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  25.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  19.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  19.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  26.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s[CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  19.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  19.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  27.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  11.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  19.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  25.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s[CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  19.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  27.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  19.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  26.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  25.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  26.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s[CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  17.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  27.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  19.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  27.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  25.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  19.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  19.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  26.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  28.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  26.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   6.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=  11.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=  10.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   9.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  18.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  13.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  13.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  22.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  15.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  14.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  10.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  10.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  10.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  17.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  13.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  29.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  27.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  26.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   5.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   5.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=   8.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=   8.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=   8.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   6.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   6.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=   9.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=   9.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  16.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  12.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   5.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=   8.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  14.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   5.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   9.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  18.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=  12.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  22.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  21.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  15.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.8s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  10.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  13.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  13.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=  10.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   7.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  17.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  16.9s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  12.7s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.3s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  16.8s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.9s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.9s
# ...
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  14.3s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.7s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.7s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  10.2s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.2s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  13.3s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  13.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   9.9s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   6.9s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  12.7s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  12.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   6.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  15.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  12.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.6s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  26.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   5.6s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   5.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=   8.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=   8.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  15.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=   8.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   6.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   6.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  12.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=   9.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=1; total time=   9.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  15.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  11.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   4.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=   7.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=   7.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  13.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  10.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   5.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   5.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=   8.0s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=   8.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  16.2s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   9.3s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  17.8s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  17.1s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  21.4s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  15.7s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  14.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   6.7s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=  10.5s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.3s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  13.0s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   9.4s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   7.2s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   7.0s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=   9.9s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=  10.2s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  16.6s
# [CV] END colsample_bytree=1, gamma=0.1, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=1; total time=  12.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1; total time=   6.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1; total time=  11.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=0.8; total time=  16.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=3, n_estimators=700, subsample=1; total time=  15.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=300, subsample=1; total time=  12.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  20.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=0.8; total time=  28.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  27.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.01, max_depth=6, n_estimators=700, subsample=1; total time=  26.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=1; total time=   5.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=1; total time=   8.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=0.8; total time=  15.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  11.3s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=3, n_estimators=700, subsample=1; total time=  11.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=0.8; total time=   8.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=300, subsample=1; total time=   6.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  12.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=500, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  15.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=0.8; total time=  15.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.1, max_depth=6, n_estimators=700, subsample=1; total time=  11.4s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   5.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=1; total time=   4.9s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=   7.8s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=1; total time=   7.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=0.8; total time=  14.1s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=3, n_estimators=700, subsample=1; total time=  10.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=1; total time=   5.2s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=0.8; total time=  10.5s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=500, subsample=1; total time=   8.0s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=1, gamma=0.5, learning_rate=0.2, max_depth=6, n_estimators=700, subsample=0.8; total time=  13.1sBest params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'subsample': 1}
# Best CV F1 Macro: 0.8412461559405114

# %%
# 👉 Sau khi train xong bạn có thể lưu best_model bằng pickle hoặc joblib
import joblib
joblib.dump(model, "xgb_best_model.pkl")
# Out:
# ['xgb_best_model.pkl']

# %%
# Lấy đặc trưng đầu vào X_test (loại bỏ cột id)
X_test = test_meta.drop(columns=['id'])

# Dự đoán nhãn dạng số
y_test_pred = model.predict(X_test)

# Lấy lại tên nhãn tương ứng
y_test_label = le.inverse_transform(y_test_pred)

# Gộp id và nhãn dự đoán
submit_df = pd.DataFrame({
    'id': test_meta['id'],
    'predict_label': y_test_label
})

# Lưu file CSV
submit_df.to_csv('submit.csv', index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [01:41:15] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
